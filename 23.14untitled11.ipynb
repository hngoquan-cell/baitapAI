# %% [markdown]
# <a href="https://colab.research.google.com/github/hngoquan-cell/baitapAI/blob/main/23.14untitled11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import time

# Giả lập trạng thái 3 xe trong 3 bước thời gian
for step in range(1, 4):
    print(f"--- Bước thời gian {step} ---")
    for car_id in range(1, 3):
        pos = np.random.rand(2) * 10
        status = "Bận" if np.random.rand() > 0.5 else "Sẵn sàng"
        print(f"Xe {car_id}: Vị trí ({pos[0]:.2f}, {pos[1]:.2f}) - Trạng thái: {status}")
    time.sleep(0.5) # Mô phỏng thời gian trôi qua
# Out:
# --- Bước thời gian 1 ---
# Xe 1: Vị trí (7.89, 4.98) - Trạng thái: Sẵn sàng
# Xe 2: Vị trí (5.37, 5.87) - Trạng thái: Bận
# --- Bước thời gian 2 ---
# Xe 1: Vị trí (4.32, 1.28) - Trạng thái: Sẵn sàng
# Xe 2: Vị trí (3.63, 6.46) - Trạng thái: Bận
# --- Bước thời gian 3 ---
# Xe 1: Vị trí (3.56, 9.87) - Trạng thái: Bận
# Xe 2: Vị trí (2.37, 1.02) - Trạng thái: Sẵn sàng
