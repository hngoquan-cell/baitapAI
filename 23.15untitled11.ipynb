# %% [markdown]
# <a href="https://colab.research.google.com/github/hngoquan-cell/baitapAI/blob/main/23.15untitled11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def ai_logistics_proposal():
    print("TÊN ĐỀ ÁN: HỆ THỐNG QUẢN LÝ LOGISTICS ĐÔ THỊ THÔNG MINH")
    print("-" * 40)
    print("1. Bài toán: Tối ưu hóa quãng đường giao hàng và giảm thời gian chờ.")
    print("2. Dữ liệu: Tọa độ GPS thời gian thực, dữ liệu lịch sử giao hàng.")
    print("3. Phương pháp AI: K-Means (Gom cụm đơn) + A* (Tìm đường) + Regression (Dự báo nhu cầu).")
    print("4. Giá trị thực tiễn: Giảm chi phí vận hành 15%, tăng mức độ hài lòng khách hàng.")

ai_logistics_proposal()
# Out:
# TÊN ĐỀ ÁN: HỆ THỐNG QUẢN LÝ LOGISTICS ĐÔ THỊ THÔNG MINH
# ----------------------------------------
# 1. Bài toán: Tối ưu hóa quãng đường giao hàng và giảm thời gian chờ.
# 2. Dữ liệu: Tọa độ GPS thời gian thực, dữ liệu lịch sử giao hàng.
# 3. Phương pháp AI: K-Means (Gom cụm đơn) + A* (Tìm đường) + Regression (Dự báo nhu cầu).
# 4. Giá trị thực tiễn: Giảm chi phí vận hành 15%, tăng mức độ hài lòng khách hàng.
